# %%
# loading the esstential libraries 

import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read the dataset 

df = pd.read_csv("/content/drive/MyDrive/creditcard.csv")
print(df.shape)
df.head()
# Out:
# (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#Unique value count
for cols in df.columns:
    unique_vals = df[cols].unique()
    if len(unique_vals) <= 10:
        print("Feature-", cols, " has ", len(unique_vals), " unique values - ", unique_vals)
    else:
        print("Feature-", cols, " has ", len(unique_vals), " unique values")
# Out:
# Feature- Time  has  124592  unique values
# Feature- V1  has  275663  unique values
# Feature- V2  has  275663  unique values
# Feature- V3  has  275663  unique values
# Feature- V4  has  275663  unique values
# Feature- V5  has  275663  unique values
# Feature- V6  has  275663  unique values
# Feature- V7  has  275663  unique values
# Feature- V8  has  275663  unique values
# Feature- V9  has  275663  unique values
# Feature- V10  has  275663  unique values
# Feature- V11  has  275663  unique values
# Feature- V12  has  275663  unique values
# Feature- V13  has  275663  unique values
# Feature- V14  has  275663  unique values
# Feature- V15  has  275663  unique values
# Feature- V16  has  275663  unique values
# Feature- V17  has  275663  unique values
# Feature- V18  has  275663  unique values
# Feature- V19  has  275663  unique values
# Feature- V20  has  275663  unique values
# Feature- V21  has  275663  unique values
# Feature- V22  has  275663  unique values
# Feature- V23  has  275663  unique values
# Feature- V24  has  275663  unique values
# Feature- V25  has  275663  unique values
# Feature- V26  has  275663  unique values
# Feature- V27  has  275663  unique values
# Feature- V28  has  275663  unique values
# Feature- Amount  has  32767  unique values
# Feature- Class  has  2  unique values -  [0 1]

# %%
## checking for null values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# remove duplicate entries, if any
df.drop_duplicates(inplace = True)
print(df.shape)
# Out:
# (283726, 31)

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x="Class", data=df)

# %%
from sklearn.preprocessing import MinMaxScaler
scale_vars = ["Amount"]
scaler = MinMaxScaler()
df[scale_vars] = scaler.fit_transform(df[scale_vars])
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28    Amount  Class
# 0 -0.189115  0.133558 -0.021053  0.005824      0
# 1  0.125895 -0.008983  0.014724  0.000105      0
# 2 -0.139097 -0.055353 -0.059752  0.014739      0
# 3 -0.221929  0.062723  0.061458  0.004807      0
# 4  0.502292  0.219422  0.215153  0.002724      0
#
# [5 rows x 31 columns]

# %%
df.value_counts("Class")
# Out:
# Class
# 0    283253
# 1       473
# dtype: int64

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x="Class", data=df)

# %%
df.value_counts("Class")
# Out:
# Class
# 0    283253
# 1       473
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scale_vars = ["Amount"]
scaler = MinMaxScaler()
df[scale_vars] = scaler.fit_transform(df[scale_vars])
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28    Amount  Class
# 0 -0.189115  0.133558 -0.021053  0.005824      0
# 1  0.125895 -0.008983  0.014724  0.000105      0
# 2 -0.139097 -0.055353 -0.059752  0.014739      0
# 3 -0.221929  0.062723  0.061458  0.004807      0
# 4  0.502292  0.219422  0.215153  0.002724      0
#
# [5 rows x 31 columns]

# %%
# Separate Independent (X) and Dependent(y) features

y = df['Class']
X = df.drop(columns = ['Class'])

# %%
#Split dataset
from sklearn.model_selection import train_test_split

# set aside 20% of train and test data for evaluation
X_train, X_test, val_train, val_test = train_test_split(X, y,
    test_size=0.2, shuffle = True, random_state = 8)

# Use the same function above for the validation set
X_train, X_test, y_train, y_test = train_test_split(X_train, val_train, 
    test_size=0.20, shuffle = True, random_state= 8) 


print("X_train shape: {}".format(X_train.shape))
print("X_test shape: {}".format(X_test.shape))
print("y_train shape: {}".format(y_train.shape))
print("y_test shape: {}".format(y_test.shape))
print("val_train shape: {}".format(val_train.shape))
print("val_test shape: {}".format(val_test.shape))
# Out:
# X_train shape: (181584, 30)
# X_test shape: (45396, 30)
# y_train shape: (181584,)
# y_test shape: (45396,)
# val_train shape: (226980,)
# val_test shape: (56746,)

# %%
df.shape
# Out:
# (283726, 31)

# %%
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount
# 0  0.128539 -0.189115  0.133558 -0.021053  0.005824
# 1  0.167170  0.125895 -0.008983  0.014724  0.000105
# 2 -0.327642 -0.139097 -0.055353 -0.059752  0.014739
# 3  0.647376 -0.221929  0.062723  0.061458  0.004807
# 4 -0.206010  0.502292  0.219422  0.215153  0.002724
#
# [5 rows x 30 columns]

# %%
plt.figure(figsize = (3,3))
ax = sns.countplot(x=y)

# %%
y_train.value_counts()
# Out:
# 0    181283
# 1       301
# Name: Class, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    45326
# 1       70
# Name: Class, dtype: int64

# %%
val_test.value_counts()
# Out:
# 0    56644
# 1      102
# Name: Class, dtype: int64

# %%
featuresWithZeroVariance = []
for cols in X_train.columns:
    unique_vals = X_train[cols].unique()
    if len(unique_vals) == 1:
        featuresWithZeroVariance.append(cols)
featuresWithZeroVariance
# Out:
# []

# %%
# Pearson's Correlation Coefficient

corr = X_train.corr()
mask1 = np.triu(np.ones_like(corr, dtype=bool))
mask2 = np.tril(np.ones_like(corr, dtype=bool))
plt.figure(figsize = (40,40))
sns.heatmap(corr, annot = True, cmap = "Greens", mask = mask1);

# %%
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of the redundant columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i, j])) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.80) # 80% value of the threshold
print(len(corr_features))
print(corr_features)
# Out:
# 0
# set()

# %%
# Decision Tree

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
maxdepths = [2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,45,50]
trainAcc = np.zeros(len(maxdepths))
testAcc = np.zeros(len(maxdepths))

index = 0
for depth in maxdepths:
    clf = DecisionTreeClassifier(max_depth=depth)
    clf = clf.fit(X_train, y_train)
    y_predTrain = clf.predict(X_train)
    y_pred_Test = clf.predict(X_test)
    trainAcc[index] = accuracy_score(y_train, y_predTrain)
    testAcc[index] = accuracy_score(y_test, y_pred_Test)
    print("Depth = ", depth, ", Training Accuracy = ", trainAcc[index], ", Test Accuracy = ", testAcc[index], 
          ", Diff = ", np.abs((trainAcc[index]-testAcc[index])*100), " %")
    index += 1

    
#########################################
# Plot of training and test accuracies
#########################################
    
plt.plot(maxdepths,trainAcc,'ro-',maxdepths,testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Max depth')
plt.ylabel('Accuracy');

#########################################
# Table for Precision, Recal & F1 Score
#########################################
from sklearn import metrics
print('-------------------------------------')
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y_test, y_pred_Test))
print()
print("Classification Report")
print(metrics.classification_report(y_test, y_pred_Test, digits = 3))
# Out:
# Depth =  2 , Training Accuracy =  0.9993391488236849 , Test Accuracy =  0.9992950920785972 , Diff =  0.004405674508767277  %
# Depth =  3 , Training Accuracy =  0.9993501630099568 , Test Accuracy =  0.9993391488236849 , Diff =  0.0011014186271918192  %
# Depth =  4 , Training Accuracy =  0.9995153758040356 , Test Accuracy =  0.9994492906864041 , Diff =  0.006608511763150915  %
# Depth =  5 , Training Accuracy =  0.9996310247598907 , Test Accuracy =  0.9994052339413164 , Diff =  0.022579081857432293  %
# Depth =  6 , Training Accuracy =  0.9996805885981144 , Test Accuracy =  0.9994713190589479 , Diff =  0.020926953916644564  %
# Depth =  7 , Training Accuracy =  0.9997081240637942 , Test Accuracy =  0.9993391488236849 , Diff =  0.03689752401092594  %
# Depth =  8 , Training Accuracy =  0.9997191382500661 , Test Accuracy =  0.9994052339413164 , Diff =  0.031390430874966846  %
# Depth =  9 , Training Accuracy =  0.9997466737157459 , Test Accuracy =  0.9993391488236849 , Diff =  0.04075248920609731  %
# Depth =  10 , Training Accuracy =  0.9997687020882897 , Test Accuracy =  0.9993171204511411 , Diff =  0.045158163714864585  %
# Depth =  15 , Training Accuracy =  0.9998788439510089 , Test Accuracy =  0.9992069785884219 , Diff =  0.06718653625870097  %
# Depth =  20 , Training Accuracy =  0.9999724645343202 , Test Accuracy =  0.9990968367257027 , Diff =  0.08756278086174962  %
# Depth =  25 , Training Accuracy =  0.999994492906864 , Test Accuracy =  0.9989426381178959 , Diff =  0.10518547889681873  %
# Depth =  30 , Training Accuracy =  1.0 , Test Accuracy =  0.9989426381178959 , Diff =  0.10573618821041464  %
# Depth =  35 , Training Accuracy =  1.0 , Test Accuracy =  0.9990748083531589 , Diff =  0.09251916468411281  %
# Depth =  40 , Training Accuracy =  1.0 , Test Accuracy =  0.999052779980615 , Diff =  0.09472200193849645  %
# Depth =  45 , Training Accuracy =  1.0 , Test Accuracy =  0.9989866948629835 , Diff =  0.10133051370164736  %
# Depth =  50 , Training Accuracy =  1.0 , Test Accuracy =  0.9990748083531589 , Diff =  0.09251916468411281  %
# -------------------------------------
# Confusion Matrix for the Test Case
# [[45301    25]
#  [   17    53]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     1.000     45326
#            1      0.679     0.757     0.716        70
#
#     accuracy                          0.999     45396
#    macro avg      0.840     0.878     0.858     45396
# weighted avg      0.999     0.999     0.999     45396

# %%
# For imbalance dataset
from sklearn.model_selection import StratifiedKFold, cross_val_score
skfold = StratifiedKFold(n_splits=5)
clf = DecisionTreeClassifier()
results = cross_val_score(clf, X, y, cv = skfold)
print(results)
print()
print ("Results = ", np.mean(results), "+/-", np.std(results))
# Out:
# [0.0054277  0.99941845 0.99592916 0.99862543 0.99887215]
#
# Results =  0.7996545759883855 +/- 0.39711527193902607

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(penalty = 'none')

clf.fit(X_train, y_train)
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
print()
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9988985813728082
# Test Accuracy:  0.998788439510089

# %%
skfold = StratifiedKFold(n_splits=5)
clf = LogisticRegression()
results = cross_val_score(clf, X, y, cv = skfold)
print(results)
print()
print ("Results = ", np.mean(results), "+/-", np.std(results))
# Out:
# [0.98042153 0.99948894 0.99897788 0.99936558 0.99871354]
#
# Results =  0.9953934957387347 +/- 0.007491068505721614
